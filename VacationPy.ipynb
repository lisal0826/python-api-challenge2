# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
import geoviews as gv
import geoviews.feature as gf
import xarray as xr
from cartopy import crs

gv.extension('bokeh', 'matplotlib')
# Out:
# c:\Users\lisal\.conda\envs\PythonData\lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated
#   "class": algorithms.Blowfish,
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
# ...

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID          City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0      waitangi -43.9535 -176.5597     17.12        85          34
# 1        1  puerto ayora  -0.7393  -90.3518     26.97        96          57
# 2        2  invercargill -46.4000  168.3500     24.12        39          44
# 3        3  longyearbyen  78.2186   15.6401    -11.09        73           0
# 4        4        bethel  41.3712  -73.4140      3.17        70         100
#
#    Wind Speed Country        Date
# 0        1.79      NZ  1707790846
# 1        1.34      EC  1707790846
# 2        3.04      NZ  1707790846
# 3        1.03      SJ  1707790846
# 4        1.54      US  1707790759

# %%
city_data_df.isnull().sum()
# Out:
# City_ID       0
# City          0
# Lat           0
# Lng           0
# Max Temp      0
# Humidity      0
# Cloudiness    0
# Wind Speed    0
# Country       5
# Date          0
# dtype: int64

# %%
print(city_data_df['Lat'].value_counts())
print(city_data_df['Lng'].value_counts())
print(city_data_df['Humidity'].value_counts())
# Out:
# Lat
#  31.5000    2
# -17.7500    2
#  49.8167    2
#  47.5649    2
# -0.6000     2
#            ..
#  67.2800    1
#  48.2156    1
#  68.7990    1
# -21.0595    1
# -8.7597     1
# Name: count, Length: 554, dtype: int64
# Lng
# -52.7093     2
#  88.1167     2
#  19.7667     2
#  156.8419    1
#  9.9833      1
#             ..
#  18.6071     1
#  16.5293     1
#  164.8658    1
#  141.9667    1
# -35.1047     1
# Name: count, Length: 556, dtype: int64
# Humidity
# 100    21
# 79     20
# 93     19
# 83     18
# 90     17
#        ..
# 19      1
# 22      1
# 35      1
# 56      1
# 12      1
# Name: count, Length: 80, dtype: int64

# %%
print(city_data_df[['Lat', 'Lng', 'Humidity']].describe())
# Out:
#               Lat         Lng    Humidity
# count  559.000000  559.000000  559.000000
# mean    17.559061   14.801971   74.098390
# std     32.630822   88.784205   21.134812
# min    -54.800000 -176.559700    8.000000
# 25%     -8.663200  -65.398650   62.000000
# 50%     18.700000   18.957000   79.000000
# 75%     45.380600   88.531950   90.000000
# max     78.218600  178.441500  100.000000

# %%
# Check the data types of columns
print(city_data_df.dtypes)
# Out:
# City_ID         int64
# City           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# Country        object
# Date            int64
# dtype: object

# %%
city_data_df.dropna()
# Out:
#      City_ID          City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          0      waitangi -43.9535 -176.5597     17.12        85          34
# 1          1  puerto ayora  -0.7393  -90.3518     26.97        96          57
# 2          2  invercargill -46.4000  168.3500     24.12        39          44
# 3          3  longyearbyen  78.2186   15.6401    -11.09        73           0
# 4          4        bethel  41.3712  -73.4140      3.17        70         100
# ..       ...           ...      ...       ...       ...       ...         ...
# 554      554         ubari  26.5921   12.7805     14.70        44           0
# 555      555       pitimbu  -7.4706  -34.8086     26.33        81          56
# 556      556     guarapari -20.6667  -40.4975     25.50        93          36
# 557      557       chengde  40.9725  117.9361      4.58        43           0
# 558      558     tamandare  -8.7597  -35.1047     24.96        91          91
#
# ...

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
pip list
# Out:
# Package                       Version
# ----------------------------- ---------------
# aiobotocore                   2.5.0
# aiofiles                      22.1.0
# aiohttp                       3.8.5
# aioitertools                  0.7.1
# aiosignal                     1.2.0
# aiosqlite                     0.18.0
# alabaster                     0.7.12
# anyio                         3.5.0
# appdirs                       1.4.4
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.2.3
# astroid                       2.14.2
# astropy                       5.1
# asttokens                     2.0.5
# async-timeout                 4.0.2
# atomicwrites                  1.4.0
# attrs                         22.1.0
# Automat                       20.2.0
# autopep8                      1.6.0
# Babel                         2.11.0
# backcall                      0.2.0
# bcrypt                        3.2.0
# ...

# %%
from cartopy import crs
# Configure the map plot
map_plot = city_data_df.hvplot.points("Lng", "Lat", c='Humidity', 
                                      geo=True, 
                                      alpha=0.5,
                                       color="City", size="Humidity", 
                                       hover_cols=['City', 'Country', 'Humidity'], 
                                       tiles=True,                                
                                       title='Cities with Humidity')


# Display the map
display(map_plot)
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Country)

# %%
city_data_df
# Out:
#      City_ID          City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          0      waitangi -43.9535 -176.5597     17.12        85          34
# 1          1  puerto ayora  -0.7393  -90.3518     26.97        96          57
# 2          2  invercargill -46.4000  168.3500     24.12        39          44
# 3          3  longyearbyen  78.2186   15.6401    -11.09        73           0
# 4          4        bethel  41.3712  -73.4140      3.17        70         100
# ..       ...           ...      ...       ...       ...       ...         ...
# 554      554         ubari  26.5921   12.7805     14.70        44           0
# 555      555       pitimbu  -7.4706  -34.8086     26.33        81          56
# 556      556     guarapari -20.6667  -40.4975     25.50        93          36
# 557      557       chengde  40.9725  117.9361      4.58        43           0
# 558      558     tamandare  -8.7597  -35.1047     24.96        91          91
#
# ...

# %%
# Define filtering criteria
criteria = (city_data_df['Max Temp'] > 20) & \
           (city_data_df['Humidity'] <= 70) & \
           (city_data_df['Cloudiness'] == 0) & \
           (city_data_df['Wind Speed'] < 5)

# Apply filtering
filtered_cities_df = city_data_df[criteria]

# Drop any rows with null values
filtered_cities_df = filtered_cities_df.dropna()

# Display sample data
print(filtered_cities_df.head())
# Out:
#      City_ID              City      Lat       Lng  Max Temp  Humidity  \
# 27        27          alaghsas  17.0187    8.0168     21.55        10
# 33        33              mora  11.0461   14.1401     22.84        12
# 122      122    margaret river -33.9500  115.0667     21.27        43
# 165      165  napili-honokowai  20.9708 -156.6705     26.64        70
# 249      249             aioun  16.6614   -9.6149     23.94         8
#
#      Cloudiness  Wind Speed Country        Date
# 27            0        4.94      NE  1707790848
# 33            0        2.51      CM  1707790848
# 122           0        4.90      AU  1707790854
# 165           0        3.30      US  1707790857
# 249           0        4.07      MR  1707790863

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Import pandas library
import pandas as pd

# Create hotel_df DataFrame using city, country, coordinates, and humidity columns from city_data_df
hotel_df = city_data_df[(city_data_df['Max Temp']>21)&(city_data_df['Max Temp']<27)&
                        (city_data_df['Cloudiness']==0)&(city_data_df['Wind Speed']<5)].copy()

hotel_df = hotel_df[['City', 'Country', 'Lat', 'Lng', 'Humidity']].copy()

# Add an empty column "Hotel Name" to store hotel information
hotel_df['Hotel Name'] = ''

# Display sample data
hotel_df
# Out:
#                  City Country      Lat       Lng  Humidity Hotel Name
# 27           alaghsas      NE  17.0187    8.0168        10
# 33               mora      CM  11.0461   14.1401        12
# 103        porto novo      BJ   6.4965    2.6036        88
# 122    margaret river      AU -33.9500  115.0667        43
# 151            bonthe      SL   7.5264  -12.5050        87
# 165  napili-honokowai      US  20.9708 -156.6705        70
# 249             aioun      MR  16.6614   -9.6149         8
# 283            bardai      NG  11.6500    7.2333        11
# 304            copala      MX  16.6500  -98.9833        82
# 370              fada      NG   9.5667    8.3000        15
# 382           reggane      DZ  26.7158    0.1714        27
# 443          karratha      AU -20.7377  116.8463        83
# 552        vila velha      BR -20.3297  -40.2925        93

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000  # Radius in meters
params = {
    "apiKey": geoapify_key, 
    "categories": "accommodation.hotel"
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # Get latitude, longitude from the DataFrame
    lat = row['Lat']
    lng = row['Lng']
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{lng},{lat},{radius}"
    params["bias"] = f"proximity:{lng},{lat}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"

    # Make an API request using the params dictionary
    response = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    response_json = response.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = response_json["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
print(hotel_df)
# Out:
# Starting hotel search
# alaghsas - nearest hotel: Hôtel Zagado
# mora - nearest hotel: Hôtel Podoko
# porto novo - nearest hotel: Hôtel 6500 CFA
# margaret river - nearest hotel: Margaret River Hotel
# bonthe - nearest hotel: No hotel found
# napili-honokowai - nearest hotel: Kahana Falls
# aioun - nearest hotel: فندق العيون
# bardai - nearest hotel: No hotel found
# copala - nearest hotel: No hotel found
# fada - nearest hotel: No hotel found
# reggane - nearest hotel: No hotel found
# karratha - nearest hotel: Karratha International Hotel
# vila velha - nearest hotel: Hotel Prainha
#                  City Country      Lat       Lng  Humidity  \
# 27           alaghsas      NE  17.0187    8.0168        10
# 33               mora      CM  11.0461   14.1401        12
# 103        porto novo      BJ   6.4965    2.6036        88
# 122    margaret river      AU -33.9500  115.0667        43
# 151            bonthe      SL   7.5264  -12.5050        87
# ...

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
hotel_df
# Out:
#                  City Country      Lat       Lng  Humidity  \
# 27           alaghsas      NE  17.0187    8.0168        10
# 33               mora      CM  11.0461   14.1401        12
# 103        porto novo      BJ   6.4965    2.6036        88
# 122    margaret river      AU -33.9500  115.0667        43
# 151            bonthe      SL   7.5264  -12.5050        87
# 165  napili-honokowai      US  20.9708 -156.6705        70
# 249             aioun      MR  16.6614   -9.6149         8
# 283            bardai      NG  11.6500    7.2333        11
# 304            copala      MX  16.6500  -98.9833        82
# 370              fada      NG   9.5667    8.3000        15
# 382           reggane      DZ  26.7158    0.1714        27
# 443          karratha      AU -20.7377  116.8463        83
# 552        vila velha      BR -20.3297  -40.2925        93
#
#                        Hotel Name
# 27                   Hôtel Zagado
# 33                   Hôtel Podoko
# ...

# %%
import geoviews as gv
gv.extension('bokeh')
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>

# %%
# %matplotlib inline

# %%
# %%capture --no-display

# Configure the map plot with additional hover columns
import hvplot.pandas  # Make sure hvplot is imported

# Create a points plot with hvplot
map_plot = hotel_df.hvplot.points(
   "Lng", "Lat",         # Longitude and Latitude for positioning
    geo=True,             # Enable geographic projection
    color="City",         # Color-code points by "City"
    hover_cols=['City', 'Country', 'Humidity', 'Hotel Name'], # Columns to show on hover
    tiles=True,
    title='Cities with Humidity',
    size="Humidity",              # Fixed size for points; adjust as needed
    alpha=0.5,            # Adjust point transparency
    legend=False          # Hide legend to manage clutter, adjust as needed



# map_plot = map_plot.opts(
  #active_tools=['wheel_zoom', 'pan'],  # Default active tools
  #tools=['hover'],  # Enable hover tool
  #width=700,        # Width of the plot
  #height=400        # Height of the plot
)

# Display the map
map_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Country,Hotel Name)

# %%
print(hotel_df.head())
# Out:
#                City Country      Lat       Lng  Humidity            Hotel Name
# 27         alaghsas      NE  17.0187    8.0168        10          Hôtel Zagado
# 33             mora      CM  11.0461   14.1401        12          Hôtel Podoko
# 103      porto novo      BJ   6.4965    2.6036        88        Hôtel 6500 CFA
# 122  margaret river      AU -33.9500  115.0667        43  Margaret River Hotel
# 151          bonthe      SL   7.5264  -12.5050        87        No hotel found
